# %%
import quantstats as qs
import numpy as np

# %%
stock = qs.utils.download_returns('AAPL')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
sharpe_ratio = qs.stats.sharpe(stock)
print(f"Sharpe Ratio:{sharpe_ratio}")
# Out:
# Sharpe Ratio:0.6117444288242074

# %% [markdown]
# This metric is crucial for understanding risk-adjusted returns.

# %%
qs.plots.drawdowns_periods(stock)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %% [markdown]
# This generates a plot highlighting major drawdown periods, crucial for risk assessment.

# %%
sp500 = qs.utils.download_returns('SPY')
qs.reports.html(stock, benchmark=sp500, output='report.html')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 sp500 = qs.utils.download_returns('SPY')
# ----> 2 qs.reports.html(stock, benchmark=sp500, output='report.html')
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/quantstats/reports.py:124, in html(returns, benchmark, rf, grayscale, title, output, compounded, periods_per_year, download_filename, figfmt, template_path, match_dates, **kwargs)
#     121 elif isinstance(returns, _pd.DataFrame):
#     122     returns.columns = strategy_title
# --> 124 mtrx = metrics(
#     125     returns=returns,
#     126     benchmark=benchmark,
#     127     rf=rf,
#     128     display=False,
#     129     mode="full",
#     130     sep=True,
#     131     internal="True",
#     132     compounded=compounded,
#     133     periods_per_year=periods_per_year,
#     134     prepare_returns=False,
#     135     benchmark_title=benchmark_title,
#     136     strategy_title=strategy_title,
#     137 )[2:]
#     139 mtrx.index.name = "Metric"
#     140 tpl = tpl.replace("{{metrics}}", _html_table(mtrx))
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/quantstats/reports.py:933, in metrics(returns, benchmark, rf, display, mode, sep, compounded, periods_per_year, prepare_returns, match_dates, **kwargs)
#     928 metrics["Kurtosis"] = _stats.kurtosis(df, prepare_returns=False)
#     930 metrics["~~~~~~~~~~"] = blank
#     932 metrics["Expected Daily %%"] = (
# --> 933     _stats.expected_return(df, compounded=compounded, prepare_returns=False) * pct
#     934 )
#     935 metrics["Expected Monthly %%"] = (
#     936     _stats.expected_return(df, compounded=compounded, aggregate="M", prepare_returns=False) * pct
#     937 )
#     938 metrics["Expected Yearly %%"] = (
#     939     _stats.expected_return(df, compounded=compounded, aggregate="A", prepare_returns=False) * pct
#     940 )
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/quantstats/stats.py:96, in expected_return(returns, aggregate, compounded, prepare_returns)
#      94     returns = _utils._prepare_returns(returns)
#      95 returns = _utils.aggregate_returns(returns, aggregate, compounded)
# ---> 96 return _np.product(1 + returns) ** (1 / len(returns)) - 1
#
# File ~/.local/lib/python3.10/site-packages/numpy/__init__.py:410, in __getattr__(attr)
#     407     import numpy.char as char
#     408     return char.chararray
# --> 410 raise AttributeError("module {!r} has no attribute "
#     411                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'product'

# %% [markdown]
# This generates an HTML report comparing the Apple stock against the S&P 500.

# %%
max_drawdown = qs.stats.max_drawdown(stock)
print(f"Maximum Drawdown : {max_drawdown}")
# Out:
# Maximum Drawdown : -0.8221656792419111
